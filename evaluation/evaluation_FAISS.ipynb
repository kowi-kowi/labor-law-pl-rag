# %%
# !pip install faiss-cpu
# !pip install -U bitsandbytes
# !pip install sentence-transformers
# !pip install rank-bm25
# Out:
# Requirement already satisfied: faiss-cpu in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (1.13.2)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: bitsandbytes in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (0.42.0)
# Requirement already satisfied: scipy in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from bitsandbytes) (1.17.0)
# Requirement already satisfied: numpy<2.7,>=1.26.4 in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from scipy->bitsandbytes) (1.26.4)
# Requirement already satisfied: sentence-transformers in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (5.2.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from sentence-transformers) (4.57.5)
# Requirement already satisfied: tqdm in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from sentence-transformers) (2.2.2)
# Requirement already satisfied: scikit-learn in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from sentence-transformers) (1.17.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (3.20.3)
# Requirement already satisfied: numpy>=1.17 in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: requests in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2026.1.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: sympy in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.1.4)
# Requirement already satisfied: joblib>=1.3.0 in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: rank-bm25 in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (0.2.2)
# Requirement already satisfied: numpy in /Users/maria/projekty/prawnik_pracy/.venv/lib/python3.11/site-packages (from rank-bm25) (1.26.4)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %%
import faiss
import json
import numpy as np
from sentence_transformers import SentenceTransformer

from transformers import AutoTokenizer, AutoModelForCausalLM
from sentence_transformers import CrossEncoder
from rank_bm25 import BM25Okapi
import torch

# %%
embedder = SentenceTransformer("sentence-transformers/paraphrase-multilingual-mpnet-base-v2")

chunks = json.load(open("/content/drive/MyDrive/prawnik_pracy/meta.json", "r", encoding="utf-8"))
index = faiss.read_index("/content/drive/MyDrive/prawnik_pracy/index.faiss")
eval_data = json.load(open("/content/drive/MyDrive/prawnik_pracy/questions.json","r",encoding="utf-8"))

# %%
bm25_corpus = [c["text"].lower().split() for c in chunks]
bm25 = BM25Okapi(bm25_corpus)

# %%
def bm25_search(query, k=20):
    scores = bm25.get_scores(query.lower().split())
    ranked_ids = np.argsort(scores)[::-1][:k]
    return [chunks[i] for i in ranked_ids if chunks[i].get("artykul")]

# %%
reranker = CrossEncoder("cross-encoder/ms-marco-MiniLM-L-6-v2")

# %%
def rerank(query, docs, top_k=5):
    pairs = [(query, d["text"]) for d in docs]
    scores = reranker.predict(pairs)

    ranked = sorted(
        zip(docs, scores),
        key=lambda x: x[1],
        reverse=True
    )

    return [d for d, s in ranked[:top_k]]

# %%
def search(query, k=5):
    emb = embedder.encode([query])
    D, I = index.search(np.array(emb), 20)

    candidates = [
        chunks[i] for i in I[0]
        if chunks[i].get("artykul")
    ]

    return rerank(query, candidates, top_k=k)

# %%
def hybrid_search(query, k=5):
    faiss_results = search(query, k=20)
    bm25_results = bm25_search(query, k=20)

    seen = set()
    merged = []

    for r in faiss_results + bm25_results:
        key = r["id"]
        if key not in seen:
            seen.add(key)
            merged.append(r)

    return rerank(query, merged, top_k=k)

# %%
hits_at_5 = 0
mrr_scores = []

# %%
import re

hits_at_5 = 0
mrr_scores = []

for item in eval_data:
    results = hybrid_search(item["question"], k=5)

    expected = item["expected_article"]
    print(f"Expected: {repr(expected)}")

    ranks = [r["artykul"] for r in results]
    print(f"Ranks found: {[repr(x) for x in ranks]}")

    query_hit = False
    query_mrr = 0.0

    for i, r_text in enumerate(ranks):
        if r_text is not None:
            # Print for debugging to see if the expected article is found within the chunk text
            print(f"  Checking if {repr(expected)} in {repr(r_text)}: {expected in r_text}")
            if expected in r_text:
                query_hit = True
                query_mrr = 1 / (i + 1)
                break  # Found the first occurrence, no need to check further for this query

    if query_hit:
        hits_at_5 += 1  # Increment total queries with a hit

    mrr_scores.append(query_mrr)  # Append one MRR score for this query

# %%
print("Hit@5:", hits_at_5 / len(eval_data))
print("MRR:", sum(mrr_scores)/len(mrr_scores))
