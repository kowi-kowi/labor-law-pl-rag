# %%
# !pip install faiss-cpu
# !pip install -U bitsandbytes
# !pip install sentence-transformers
# !pip install rank-bm25
# Out:
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.12/dist-packages (1.13.2)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.12/dist-packages (0.49.1)
# Requirement already satisfied: torch<3,>=2.3 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.9.0+cu126)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.20.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3,>=2.3->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=2.3->bitsandbytes) (3.0.3)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (5.2.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.57.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (2.9.0+cu126)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.20.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.5.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2026.1.4)
# Collecting rank-bm25
#   Downloading rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rank-bm25) (2.0.2)
# Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Installing collected packages: rank-bm25
# Successfully installed rank-bm25-0.2.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import faiss
import json
import numpy as np
from sentence_transformers import SentenceTransformer

from transformers import AutoTokenizer, AutoModelForCausalLM
from sentence_transformers import CrossEncoder
from rank_bm25 import BM25Okapi
import torch

# %%
embedder = SentenceTransformer("sentence-transformers/paraphrase-multilingual-mpnet-base-v2")

chunks = json.load(open("/content/drive/MyDrive/prawnik_pracy/meta.json", "r", encoding="utf-8"))
index = faiss.read_index("/content/drive/MyDrive/prawnik_pracy/index.faiss")
eval_data = json.load(open("/content/drive/MyDrive/prawnik_pracy/questions.json","r",encoding="utf-8"))

# %%
bm25_corpus = [c["text"].lower().split() for c in chunks]
bm25 = BM25Okapi(bm25_corpus)

# %%
def bm25_search(query, k=20):
    scores = bm25.get_scores(query.lower().split())
    ranked_ids = np.argsort(scores)[::-1][:k]
    return [chunks[i] for i in ranked_ids if chunks[i].get("artykul")]

# %%
reranker = CrossEncoder("cross-encoder/ms-marco-MiniLM-L-6-v2")
# Out:
# config.json:   0%|          | 0.00/794 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]

# %%
def rerank(query, docs, top_k=5):
    pairs = [(query, d["text"]) for d in docs]
    scores = reranker.predict(pairs)

    ranked = sorted(
        zip(docs, scores),
        key=lambda x: x[1],
        reverse=True
    )

    return [d for d, s in ranked[:top_k]]

# %%
def search(query, k=5):
    emb = embedder.encode([query])
    D, I = index.search(np.array(emb), 20)

    candidates = [
        chunks[i] for i in I[0]
        if chunks[i].get("artykul")
    ]

    return rerank(query, candidates, top_k=k)

# %%
def hybrid_search(query, k=5):
    faiss_results = search(query, k=20)
    bm25_results = bm25_search(query, k=20)

    seen = set()
    merged = []

    for r in faiss_results + bm25_results:
        key = r["id"]
        if key not in seen:
            seen.add(key)
            merged.append(r)

    return rerank(query, merged, top_k=k)

# %%
hits_at_5 = 0
mrr_scores = []

# %%
import re

hits_at_5 = 0
mrr_scores = []

for item in eval_data:
    results = hybrid_search(item["question"], k=5)

    expected = item["expected_article"]
    print(f"Expected: {repr(expected)}")

    ranks = [r["artykul"] for r in results]
    print(f"Ranks found: {[repr(x) for x in ranks]}")

    query_hit = False
    query_mrr = 0.0

    for i, r_text in enumerate(ranks):
        if r_text is not None:
            # Print for debugging to see if the expected article is found within the chunk text
            print(f"  Checking if {repr(expected)} in {repr(r_text)}: {expected in r_text}")
            if expected in r_text:
                query_hit = True
                query_mrr = 1 / (i + 1)
                break  # Found the first occurrence, no need to check further for this query

    if query_hit:
        hits_at_5 += 1  # Increment total queries with a hit

    mrr_scores.append(query_mrr)  # Append one MRR score for this query
# Out:
# Expected: 'Art. 1'
# Ranks found: ["'Art. 1. Kodeks pracy określa prawa i obowiązki pracowników i pracodawców.'", "'Art. 5. Jeżeli stosunek pracy określonej kategorii pracowników regulują przepisy szczególne, przepisy kodeksu stosuje się'", "'Art. 9. § 1. Ilekroć w Kodeksie pracy jest mowa o prawie pracy, rozumie się przez to przepisy Kodeksu pracy oraz'", "'Art. 6732. W przypadku wykonywania pracy zdalnej wnioski pracownika, dla których przepisy kodeksu lub innych'", "'Art. 297. Minister Pracy i Polityki Socjalnej10) określi w drodze rozporządzenia:'"]
#   Checking if 'Art. 1' in 'Art. 1. Kodeks pracy określa prawa i obowiązki pracowników i pracodawców.': True
# Expected: 'Art. 9'
# Ranks found: ["'Art. 10. § 1. Każdy ma prawo do swobodnie wybranej pracy. Nikomu, z wyjątkiem przypadków określonych w ustawie,'", "'Art. 187. § 1. Pracownica karmiąca dziecko piersią ma prawo do dwóch półgodzinnych przerw w pracy wliczanych'", "'Art. 77. § 1. Stosunek pracy między spółdzielnią pracy a jej członkiem nawiązuje się przez spółdzielczą umowę o pracę.'", "'Art. 683. Jeżeli pracownik powołany na stanowisko w wyniku konkursu pozostaje w stosunku pracy z innym praco-'", "'Art. 80. Wynagrodzenie przysługuje za pracę wykonaną. Za czas niewykonywania pracy pracownik zachowuje prawo'"]
#   Checking if 'Art. 9' in 'Art. 10. § 1. Każdy ma prawo do swobodnie wybranej pracy. Nikomu, z wyjątkiem przypadków określonych w ustawie,': False
#   Checking if 'Art. 9' in 'Art. 187. § 1. Pracownica karmiąca dziecko piersią ma prawo do dwóch półgodzinnych przerw w pracy wliczanych': False
#   Checking if 'Art. 9' in 'Art. 77. § 1. Stosunek pracy między spółdzielnią pracy a jej członkiem nawiązuje się przez spółdzielczą umowę o pracę.': False
#   Checking if 'Art. 9' in 'Art. 683. Jeżeli pracownik powołany na stanowisko w wyniku konkursu pozostaje w stosunku pracy z innym praco-': False
#   Checking if 'Art. 9' in 'Art. 80. Wynagrodzenie przysługuje za pracę wykonaną. Za czas niewykonywania pracy pracownik zachowuje prawo': False
# Expected: 'Art. 22'
# Ranks found: ["'Art. 73. § 1. Nawiązanie stosunku pracy następuje na podstawie wyboru, jeżeli z wyboru wynika obowiązek wykony-'", "'Art. 77. § 1. Stosunek pracy między spółdzielnią pracy a jej członkiem nawiązuje się przez spółdzielczą umowę o pracę.'", "'Art. 68. § 1. Stosunek pracy nawiązuje się na podstawie powołania w przypadkach określonych w odrębnych przepisach.'", "'Art. 683. Jeżeli pracownik powołany na stanowisko w wyniku konkursu pozostaje w stosunku pracy z innym praco-'", "'Art. 76. Stosunek pracy nawiązuje się na podstawie mianowania w przypadkach określonych w odrębnych przepisach.'"]
#   Checking if 'Art. 22' in 'Art. 73. § 1. Nawiązanie stosunku pracy następuje na podstawie wyboru, jeżeli z wyboru wynika obowiązek wykony-': False
#   Checking if 'Art. 22' in 'Art. 77. § 1. Stosunek pracy między spółdzielnią pracy a jej członkiem nawiązuje się przez spółdzielczą umowę o pracę.': False
#   Checking if 'Art. 22' in 'Art. 68. § 1. Stosunek pracy nawiązuje się na podstawie powołania w przypadkach określonych w odrębnych przepisach.': False
#   Checking if 'Art. 22' in 'Art. 683. Jeżeli pracownik powołany na stanowisko w wyniku konkursu pozostaje w stosunku pracy z innym praco-': False
#   Checking if 'Art. 22' in 'Art. 76. Stosunek pracy nawiązuje się na podstawie mianowania w przypadkach określonych w odrębnych przepisach.': False
# Expected: 'Art. 261'
# Ranks found: ["'Art. 261. § 1. Pracodawca nie może zakazać pracownikowi jednoczesnego pozostawania w stosunku pracy z innym'", "'Art. 71. Na wniosek lub za zgodą pracownika pracodawca może zatrudnić go w okresie wypowiedzenia przy innej'", "'Art. 1781. Pracodawca zatrudniający pracownicę w porze nocnej jest obowiązany na okres jej ciąży zmienić rozkład'", "'Art. 1515. § 1. Pracodawca może zobowiązać pracownika do pozostawania poza normalnymi godzinami pracy w goto-'", "'Art. 971. § 1. W przypadku niewydania przez pracodawcę świadectwa pracy pracownikowi przysługuje prawo wystą-'"]
#   Checking if 'Art. 261' in 'Art. 261. § 1. Pracodawca nie może zakazać pracownikowi jednoczesnego pozostawania w stosunku pracy z innym': True
# Expected: 'Art. 229'
# Ranks found: ["'Art. 167. § 1. Pracodawca może odwołać pracownika z urlopu tylko wówczas, gdy jego obecności w zakładzie wyma-'", "'Art. 229. § 1. Wstępnym badaniom lekarskim, z zastrzeżeniem § 11, podlegają:'", "'Art. 258. § 1. Pracodawca jest obowiązany zapewnić komisji pojednawczej warunki lokalowe oraz środki techniczne'", "'Art. 115. Pracownik ponosi odpowiedzialność za szkodę w granicach rzeczywistej straty poniesionej przez praco-'", "'Art. 117. § 1. Pracownik nie ponosi odpowiedzialności za szkodę w takim zakresie, w jakim pracodawca lub inna'"]
#   Checking if 'Art. 229' in 'Art. 167. § 1. Pracodawca może odwołać pracownika z urlopu tylko wówczas, gdy jego obecności w zakładzie wyma-': False
#   Checking if 'Art. 229' in 'Art. 229. § 1. Wstępnym badaniom lekarskim, z zastrzeżeniem § 11, podlegają:': True
# Expected: 'Art. 29'
# Ranks found: ["'Art. 38. § 1. O zamiarze wypowiedzenia pracownikowi umowy o pracę zawartej na czas określony lub umowy o pracę'", "'Art. 50. § 1. Jeżeli wypowiedzenie umowy o pracę zawartej na okres próbny nastąpiło z naruszeniem przepisów o wy-'", "'Art. 59. W razie rozwiązania przez pracodawcę umowy o pracę zawartej na czas określony z naruszeniem przepisów'", "'Art. 30. § 1. Umowa o pracę rozwiązuje się:'", "'Art. 195. § 1. Umowa o pracę w celu przygotowania zawodowego powinna określać w szczególności:'"]
#   Checking if 'Art. 29' in 'Art. 38. § 1. O zamiarze wypowiedzenia pracownikowi umowy o pracę zawartej na czas określony lub umowy o pracę': False
#   Checking if 'Art. 29' in 'Art. 50. § 1. Jeżeli wypowiedzenie umowy o pracę zawartej na okres próbny nastąpiło z naruszeniem przepisów o wy-': False
#   Checking if 'Art. 29' in 'Art. 59. W razie rozwiązania przez pracodawcę umowy o pracę zawartej na czas określony z naruszeniem przepisów': False
#   Checking if 'Art. 29' in 'Art. 30. § 1. Umowa o pracę rozwiązuje się:': False
#   Checking if 'Art. 29' in 'Art. 195. § 1. Umowa o pracę w celu przygotowania zawodowego powinna określać w szczególności:': False
# Expected: 'Art. 63'
# Ranks found: ["'Art. 63. Umowa o pracę wygasa w przypadkach określonych w kodeksie oraz w przepisach szczególnych.'", "'Art. 66. § 1. Umowa o pracę wygasa z upływem 3 miesięcy nieobecności pracownika w pracy z powodu tymczaso-'", "'Art. 632. § 1. Z dniem śmierci pracodawcy umowy o pracę z pracownikami wygasają, z zastrzeżeniem § 3–11.'", "'Art. 50. § 1. Jeżeli wypowiedzenie umowy o pracę zawartej na okres próbny nastąpiło z naruszeniem przepisów o wy-'", "'Art. 59. W razie rozwiązania przez pracodawcę umowy o pracę zawartej na czas określony z naruszeniem przepisów'"]
#   Checking if 'Art. 63' in 'Art. 63. Umowa o pracę wygasa w przypadkach określonych w kodeksie oraz w przepisach szczególnych.': True
# Expected: 'Art. 262'
# Ranks found: ["'Art. 262. § 1. Spory o roszczenia ze stosunku pracy rozstrzygają sądy powszechne, zwane „sądami pracy”.'", "'Art. 242. § 1. Pracownik może dochodzić swych roszczeń ze stosunku pracy na drodze sądowej.'", "'Art. 244. § 1. W celu polubownego załatwiania sporów o roszczenia pracowników ze stosunku pracy mogą być powoły-'", "'Art. 292. Po upływie terminu przedawnienia roszczenia ze stosunku pracy ten, przeciwko komu przysługuje roszcze-'", "'Art. 243. Pracodawca i pracownik powinni dążyć do polubownego załatwienia sporu ze stosunku pracy.'"]
#   Checking if 'Art. 262' in 'Art. 262. § 1. Spory o roszczenia ze stosunku pracy rozstrzygają sądy powszechne, zwane „sądami pracy”.': True
# Expected: 'Art. 943'
# Ranks found: ["'Art. 128. § 1. Czasem pracy jest czas, w którym pracownik pozostaje w dyspozycji pracodawcy w zakładzie pracy lub'", "'Art. 304. § 1. Pracodawca jest obowiązany zapewnić bezpieczne i higieniczne warunki pracy, o których mowa w art. 207'", "'Art. 23710. § 1. Pracodawca jest obowiązany zapewnić, aby środki ochrony indywidualnej oraz odzież i obuwie robo-'", "'Art. 22. § 1. Przez nawiązanie stosunku pracy pracownik zobowiązuje się do wykonywania pracy określonego rodzaju'", "'Art. 141. § 1. Pracodawca może wprowadzić jedną przerwę w pracy niewliczaną do czasu pracy, w wymiarze nieprze-'"]
#   Checking if 'Art. 943' in 'Art. 128. § 1. Czasem pracy jest czas, w którym pracownik pozostaje w dyspozycji pracodawcy w zakładzie pracy lub': False
#   Checking if 'Art. 943' in 'Art. 304. § 1. Pracodawca jest obowiązany zapewnić bezpieczne i higieniczne warunki pracy, o których mowa w art. 207': False
#   Checking if 'Art. 943' in 'Art. 23710. § 1. Pracodawca jest obowiązany zapewnić, aby środki ochrony indywidualnej oraz odzież i obuwie robo-': False
#   Checking if 'Art. 943' in 'Art. 22. § 1. Przez nawiązanie stosunku pracy pracownik zobowiązuje się do wykonywania pracy określonego rodzaju': False
#   Checking if 'Art. 943' in 'Art. 141. § 1. Pracodawca może wprowadzić jedną przerwę w pracy niewliczaną do czasu pracy, w wymiarze nieprze-': False
# Expected: 'Art. 113'
# Ranks found: ["'Art. 232. Pracodawca jest obowiązany zapewnić pracownikom zatrudnionym w warunkach szczególnie uciążliwych,'", "'Art. 23710. § 1. Pracodawca jest obowiązany zapewnić, aby środki ochrony indywidualnej oraz odzież i obuwie robo-'", "'Art. 1781. Pracodawca zatrudniający pracownicę w porze nocnej jest obowiązany na okres jej ciąży zmienić rozkład'", "'Art. 80. Wynagrodzenie przysługuje za pracę wykonaną. Za czas niewykonywania pracy pracownik zachowuje prawo'", "'Art. 1721. § 1. Jeżeli pracodawca na podstawie odrębnych przepisów jest obowiązany objąć pracownika ubezpiecze-'"]
#   Checking if 'Art. 113' in 'Art. 232. Pracodawca jest obowiązany zapewnić pracownikom zatrudnionym w warunkach szczególnie uciążliwych,': False
#   Checking if 'Art. 113' in 'Art. 23710. § 1. Pracodawca jest obowiązany zapewnić, aby środki ochrony indywidualnej oraz odzież i obuwie robo-': False
#   Checking if 'Art. 113' in 'Art. 1781. Pracodawca zatrudniający pracownicę w porze nocnej jest obowiązany na okres jej ciąży zmienić rozkład': False
#   Checking if 'Art. 113' in 'Art. 80. Wynagrodzenie przysługuje za pracę wykonaną. Za czas niewykonywania pracy pracownik zachowuje prawo': False
#   Checking if 'Art. 113' in 'Art. 1721. § 1. Jeżeli pracodawca na podstawie odrębnych przepisów jest obowiązany objąć pracownika ubezpiecze-': False
# Expected: 'Art. 183a'
# Ranks found: ["'Art. 112. Pracownicy mają równe prawa z tytułu jednakowego wypełniania takich samych obowiązków; dotyczy to'", "'Art. 183b. § 1. Za naruszenie zasady równego traktowania w zatrudnieniu, z zastrzeżeniem § 2–4, uważa się różnico-'", "'Art. 183a. § 1. Pracownicy powinni być równo traktowani w zakresie nawiązania i rozwiązania stosunku pracy, warun-'", "'Art. 183d. Osoba, wobec której pracodawca naruszył zasadę równego traktowania w zatrudnieniu, ma prawo do odszkodo-'", "'Art. 183e. § 1. Skorzystanie przez pracownika z uprawnień przysługujących z tytułu naruszenia przepisów prawa'"]
#   Checking if 'Art. 183a' in 'Art. 112. Pracownicy mają równe prawa z tytułu jednakowego wypełniania takich samych obowiązków; dotyczy to': False
#   Checking if 'Art. 183a' in 'Art. 183b. § 1. Za naruszenie zasady równego traktowania w zatrudnieniu, z zastrzeżeniem § 2–4, uważa się różnico-': False
#   Checking if 'Art. 183a' in 'Art. 183a. § 1. Pracownicy powinni być równo traktowani w zakresie nawiązania i rozwiązania stosunku pracy, warun-': True
# Expected: 'Art. 207'
# Ranks found: ["'Art. 215. Pracodawca jest obowiązany zapewnić, aby stosowane maszyny i inne urządzenia techniczne:'", "'Art. 15. Pracodawca jest obowiązany zapewnić pracownikom bezpieczne i higieniczne warunki pracy.'", "'Art. 232. Jeżeli przepisy prawa pracy przewidują współdziałanie pracodawcy z zakładową organizacją związkową'", "'Art. 214. § 1. Pracodawca jest obowiązany zapewniać pomieszczenia pracy odpowiednie do rodzaju wykonywanych'", "'Art. 2374. § 1. Pracodawca jest obowiązany zaznajamiać pracowników z przepisami i zasadami bezpieczeństwa i higieny'"]
#   Checking if 'Art. 207' in 'Art. 215. Pracodawca jest obowiązany zapewnić, aby stosowane maszyny i inne urządzenia techniczne:': False
#   Checking if 'Art. 207' in 'Art. 15. Pracodawca jest obowiązany zapewnić pracownikom bezpieczne i higieniczne warunki pracy.': False
#   Checking if 'Art. 207' in 'Art. 232. Jeżeli przepisy prawa pracy przewidują współdziałanie pracodawcy z zakładową organizacją związkową': False
#   Checking if 'Art. 207' in 'Art. 214. § 1. Pracodawca jest obowiązany zapewniać pomieszczenia pracy odpowiednie do rodzaju wykonywanych': False
#   Checking if 'Art. 207' in 'Art. 2374. § 1. Pracodawca jest obowiązany zaznajamiać pracowników z przepisami i zasadami bezpieczeństwa i higieny': False
# Expected: 'Art. 100'
# Ranks found: ["'Art. 232. Jeżeli przepisy prawa pracy przewidują współdziałanie pracodawcy z zakładową organizacją związkową'", "'Art. 9413. Jeżeli obowiązek pracodawcy przeprowadzenia szkoleń pracowników niezbędnych do wykonywania określonego'", "'Art. 100. § 1. Pracownik jest obowiązany wykonywać pracę sumiennie i starannie oraz stosować się do poleceń prze-'", "'Art. 1041. § 1. Regulamin pracy, określając prawa i obowiązki pracodawcy i pracowników związane z porządkiem'", "'Art. 2002. § 1. Pracodawca ustala wymiar i rozkład czasu pracy młodocianego zatrudnionego przy lekkiej pracy,'"]
#   Checking if 'Art. 100' in 'Art. 232. Jeżeli przepisy prawa pracy przewidują współdziałanie pracodawcy z zakładową organizacją związkową': False
#   Checking if 'Art. 100' in 'Art. 9413. Jeżeli obowiązek pracodawcy przeprowadzenia szkoleń pracowników niezbędnych do wykonywania określonego': False
#   Checking if 'Art. 100' in 'Art. 100. § 1. Pracownik jest obowiązany wykonywać pracę sumiennie i starannie oraz stosować się do poleceń prze-': True
# Expected: 'Art. 221c'
# Ranks found: ["'Art. 1033. Pracodawca może przyznać pracownikowi podnoszącemu kwalifikacje zawodowe dodatkowe świadczenia,'", "'Art. 167. § 1. Pracodawca może odwołać pracownika z urlopu tylko wówczas, gdy jego obecności w zakładzie wyma-'", "'Art. 71. Na wniosek lub za zgodą pracownika pracodawca może zatrudnić go w okresie wypowiedzenia przy innej'", "'Art. 2379. § 1. Pracodawca nie może dopuścić pracownika do pracy bez środków ochrony indywidualnej oraz odzieży'", "'Art. 41. Pracodawca nie może wypowiedzieć umowy o pracę w czasie urlopu pracownika, a także w czasie innej'"]
#   Checking if 'Art. 221c' in 'Art. 1033. Pracodawca może przyznać pracownikowi podnoszącemu kwalifikacje zawodowe dodatkowe świadczenia,': False
#   Checking if 'Art. 221c' in 'Art. 167. § 1. Pracodawca może odwołać pracownika z urlopu tylko wówczas, gdy jego obecności w zakładzie wyma-': False
#   Checking if 'Art. 221c' in 'Art. 71. Na wniosek lub za zgodą pracownika pracodawca może zatrudnić go w okresie wypowiedzenia przy innej': False
#   Checking if 'Art. 221c' in 'Art. 2379. § 1. Pracodawca nie może dopuścić pracownika do pracy bez środków ochrony indywidualnej oraz odzieży': False
#   Checking if 'Art. 221c' in 'Art. 41. Pracodawca nie może wypowiedzieć umowy o pracę w czasie urlopu pracownika, a także w czasie innej': False
# Expected: 'Art. 97'
# Ranks found: ["'Art. 971. § 1. W przypadku niewydania przez pracodawcę świadectwa pracy pracownikowi przysługuje prawo wystą-'", "'Art. 97. § 1. W związku z rozwiązaniem lub wygaśnięciem stosunku pracy pracodawca jest obowiązany wydać pracow-'", "'Art. 946. W przypadku rozwiązania lub wygaśnięcia stosunku pracy pracodawca wraz ze świadectwem pracy wydaje'", "'Art. 99. § 1. Pracownikowi przysługuje roszczenie o naprawienie szkody wyrządzonej przez pracodawcę wskutek nie-'", "'Art. 2374. § 1. Pracodawca jest obowiązany zaznajamiać pracowników z przepisami i zasadami bezpieczeństwa i higieny'"]
#   Checking if 'Art. 97' in 'Art. 971. § 1. W przypadku niewydania przez pracodawcę świadectwa pracy pracownikowi przysługuje prawo wystą-': True
# Expected: 'Art. 152'
# Ranks found: ["'Art. 152. § 1. Pracownikowi przysługuje prawo do corocznego, nieprzerwanego, płatnego urlopu wypoczynkowego,'", "'Art. 14. Pracownik ma prawo do wypoczynku, który zapewniają przepisy o czasie pracy, dniach wolnych od pracy'", "'Art. 1862. § 1. W czasie urlopu wychowawczego pracownik ma prawo podjąć pracę zarobkową u dotychczasowego'", "'Art. 161. Pracodawca jest obowiązany udzielić pracownikowi urlopu w tym roku kalendarzowym, w którym pracownik'", "'Art. 153. § 1. Pracownik podejmujący pracę po raz pierwszy, w roku kalendarzowym, w którym podjął pracę, uzyskuje'"]
#   Checking if 'Art. 152' in 'Art. 152. § 1. Pracownikowi przysługuje prawo do corocznego, nieprzerwanego, płatnego urlopu wypoczynkowego,': True
# Expected: 'Art. 154'
# Ranks found: ["'Art. 154. § 1. Wymiar urlopu wynosi:'", "'Art. 1542. § 1. Urlopu udziela się w dni, które są dla pracownika dniami pracy, zgodnie z obowiązującym go rozkła-'", "'Art. 1673. Łączny wymiar urlopu wykorzystanego przez pracownika na zasadach i w trybie określonych w art. 1672'", "'Art. 155. § 1. Do okresu pracy, od którego zależy wymiar urlopu, wlicza się z tytułu ukończenia:'", "'Art. 1553. § 1. Przy ustalaniu wymiaru urlopu na podstawie art. 1551 i 1552 niepełny dzień urlopu zaokrągla się w górę do'"]
#   Checking if 'Art. 154' in 'Art. 154. § 1. Wymiar urlopu wynosi:': True
# Expected: 'Art. 177'
# Ranks found: ["'Art. 47. Pracownikowi, który podjął pracę w wyniku przywrócenia do pracy, przysługuje wynagrodzenie za czas po-'", "'Art. 57. § 1. Pracownikowi, który podjął pracę w wyniku przywrócenia do pracy, przysługuje wynagrodzenie za czas'", "'Art. 201. § 1. Młodociany podlega wstępnym badaniom lekarskim przed przyjęciem do pracy oraz badaniom okreso-'", "'Art. 182. W przypadku porzucenia dziecka przez pracownicę lub umieszczenia dziecka, na podstawie orzeczenia'", "'Art. 282. § 1. Kto, wbrew obowiązkowi:'"]
#   Checking if 'Art. 177' in 'Art. 47. Pracownikowi, który podjął pracę w wyniku przywrócenia do pracy, przysługuje wynagrodzenie za czas po-': False
#   Checking if 'Art. 177' in 'Art. 57. § 1. Pracownikowi, który podjął pracę w wyniku przywrócenia do pracy, przysługuje wynagrodzenie za czas': False
#   Checking if 'Art. 177' in 'Art. 201. § 1. Młodociany podlega wstępnym badaniom lekarskim przed przyjęciem do pracy oraz badaniom okreso-': False
#   Checking if 'Art. 177' in 'Art. 182. W przypadku porzucenia dziecka przez pracownicę lub umieszczenia dziecka, na podstawie orzeczenia': False
#   Checking if 'Art. 177' in 'Art. 282. § 1. Kto, wbrew obowiązkowi:': False
# Expected: 'Art. 41'
# Ranks found: ["'Art. 52. § 1. Pracodawca może rozwiązać umowę o pracę bez wypowiedzenia z winy pracownika w razie:'", "'Art. 60. Jeżeli pracodawca rozwiązał umowę o pracę w okresie wypowiedzenia z naruszeniem przepisów o rozwiązy-'", "'Art. 43. Pracodawca może wypowiedzieć warunki pracy lub płacy pracownikowi, o którym mowa w art. 39, jeżeli'", "'Art. 39. Pracodawca nie może wypowiedzieć umowy o pracę pracownikowi, któremu brakuje nie więcej niż 4 lata do'", "'Art. 41. Pracodawca nie może wypowiedzieć umowy o pracę w czasie urlopu pracownika, a także w czasie innej'"]
#   Checking if 'Art. 41' in 'Art. 52. § 1. Pracodawca może rozwiązać umowę o pracę bez wypowiedzenia z winy pracownika w razie:': False
#   Checking if 'Art. 41' in 'Art. 60. Jeżeli pracodawca rozwiązał umowę o pracę w okresie wypowiedzenia z naruszeniem przepisów o rozwiązy-': False
#   Checking if 'Art. 41' in 'Art. 43. Pracodawca może wypowiedzieć warunki pracy lub płacy pracownikowi, o którym mowa w art. 39, jeżeli': False
#   Checking if 'Art. 41' in 'Art. 39. Pracodawca nie może wypowiedzieć umowy o pracę pracownikowi, któremu brakuje nie więcej niż 4 lata do': False
#   Checking if 'Art. 41' in 'Art. 41. Pracodawca nie może wypowiedzieć umowy o pracę w czasie urlopu pracownika, a także w czasie innej': True
# Expected: 'Art. 9'
# Ranks found: ["'Art. 24126. § 1. Postanowienia układu zakładowego nie mogą być mniej korzystne dla pracowników niż postanowienia'", "'Art. 231a. § 1. Jeżeli jest to uzasadnione sytuacją finansową pracodawcy, nieobjętego układem zbiorowym pracy lub'", "'Art. 6729. § 1. Pracownik wykonujący pracę zdalną nie może być traktowany mniej korzystnie w zakresie nawiązania'", "'Art. 172. Za czas urlopu pracownikowi przysługuje wynagrodzenie, jakie by otrzymał, gdyby w tym czasie pracował.'", "'Art. 143. Na pisemny wniosek pracownika może być do niego stosowany system skróconego tygodnia pracy. W tym'"]
#   Checking if 'Art. 9' in 'Art. 24126. § 1. Postanowienia układu zakładowego nie mogą być mniej korzystne dla pracowników niż postanowienia': False
#   Checking if 'Art. 9' in 'Art. 231a. § 1. Jeżeli jest to uzasadnione sytuacją finansową pracodawcy, nieobjętego układem zbiorowym pracy lub': False
#   Checking if 'Art. 9' in 'Art. 6729. § 1. Pracownik wykonujący pracę zdalną nie może być traktowany mniej korzystnie w zakresie nawiązania': False
#   Checking if 'Art. 9' in 'Art. 172. Za czas urlopu pracownikowi przysługuje wynagrodzenie, jakie by otrzymał, gdyby w tym czasie pracował.': False
#   Checking if 'Art. 9' in 'Art. 143. Na pisemny wniosek pracownika może być do niego stosowany system skróconego tygodnia pracy. W tym': False

# %%
print("Hit@5:", hits_at_5 / len(eval_data))
print("MRR:", sum(mrr_scores)/len(mrr_scores))
# Out:
# Hit@5: 0.55
# MRR: 0.41833333333333333
